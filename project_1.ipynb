# %% [markdown]
# <a href="https://colab.research.google.com/github/khan085796-collab/Aftab-_edurkon-_2026-DS/blob/main/project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x ="Edukron Data Science and Data Engineering Batch 2026"

# %%
print(x)
# Out:
# Edukron Data Science and Data Engineering Batch

# %%
x[0:7]
# Out:
# 'Edukron'

# %%
print(len(x))
# Out:
# 52

# %%
x[8:12]
# Out:
# 'Data'

# %%
x[13:20]
# Out:
# 'Science'

# %%
x[21:24]
# Out:
# 'and'

# %%
x[25:29]
# Out:
# 'Data'

# %%
x[30:41]
# Out:
# 'Engineering'

# %%
x[42:47]
# Out:
# 'Batch'

# %%
x[48:52]
# Out:
# '2026'

# %%
x[13:29]
# Out:
# 'Science and Data'

# %%
len(x)
# Out:
# 52

# %%
x[-4:]
# Out:
# '2026'

# %%
x[0:]
# Out:
# 'Edukron Data Science and Data Engineering Batch 2026'

# %%
x[-10:-5]
# Out:
# 'Batch'

# %%
x[-22:-11]
# Out:
# 'Engineering'

# %%
x[-27:-23]
# Out:
# 'Data'

# %%
x[-31:-28]
# Out:
# 'and'

# %%
x[-39:-32]
# Out:
# 'Science'

# %%
x[-44:-40]
# Out:
# 'Data'

# %%
x[-52:-45]
# Out:
# 'Edukron'
